# %% [markdown]
# <a href="https://colab.research.google.com/github/Zenzo-Ikeda/first-git/blob/master/C%2B%2B_cheat_sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新しいセクション

# %% [markdown]
# ## at code の<stdc++.h>に含まれる主なモジュール
#
#  #include <iostream> // cout, endl, cin<br>
#  #include <string> // string, to_string, stoi<br>
#  #include <vector> // vector<br>
#  #include <algorithm> // min, max, swap, sort, reverse, lower_bound, upper_bound<br>
#  #include <utility> // pair, make_pair<br>
#  #include <tuple> // tuple, make_tuple<br>
#  #include <cstdint> // int64_t, int*_t<br>
#  #include <cstdio> // printf<br>
#  #include <map> // map<br>
#  #include <queue> // queue, priority_queue<br>
#  #include <set> // set<br>
#  #include <stack> // stack
#  #include <deque> // deque<br>
#  #include <unordered_map> // unordered_map<br>
#  #include <unordered_set> // unordered_set<br>
#  #include <bitset> // bitset<br>
#  #include <cctype> // isupper, islower, isdigit, toupper, tolower<br>
#
#
# ## 主な数型
#
# #### 符号付き整数型
# |型	　　　　　   |扱える値の範囲	  | 使用するメモリ量|
# |       ----    |   ----               |   ----        |
# |signed char		|-2^7  〜 2^7-1		|1 byte (8 bit)      |
# |short	  	  	|−2-15 〜 2^15-1  |	2 byte (16 bit)  |
# |int	        	|	−2^31 〜 2^31-1 |	4 byte (32 bit)  |
# |long long   		|−2^63 〜 2^63-1	|	8 byte (64 bit) |
# |int64_t	   		|−2^63 〜 2^63-1	|	8 byte (64 bit) |
#
# //long のサイズは環境に依存(32bitまたは64bit)
#
# #### 符号無し整数型
# |      |      |      |
# | ---- | ---- | ---- |
# |unsigned char	 |0〜2^8-1		|1 byte (8 bit) |
# |unsigned short	 |0〜2^16-1 	|	2 byte (16 bit)|
# |unsigned int	   |0〜2^32-1		|	4 byte (32 bit)|
# |uint64_t	       |0〜2^64-1		|	8 byte (64 bit)|
#
# #### 実数型
# |型	　	|扱える値の範囲(絶対値)	 | 扱える精度(10進数)	| 使用するメモリ量 |
# |----|----|----|----|
# |float	|約1.17×10^−38 〜 約3.40×10^38  	 |約8桁	    |4 byte (32 bit) |
# |double	|約2.22×10^-308 〜 約1.79×10 ^308  |約16桁	  |8 byte (64 bit) |
#
# ## stdin stdout
# ### console in / out
# `cin >> a , b , c;` &nbsp; //スペース、改行文字(\n),タブ(\t)ごとに区切られて変数に代入<br>
# 配列に代入する場合は &nbsp;　`int A[配列の最大サイズ];` //と宣言してから
#           `for (int i = 0; i < N: i++) cin >> A[i];`<br>
#   vector <int> A を使う方法もあり。（at corder 公式推奨）
# `getline(cin, s);` &nbsp; //1行分の文字列をsに代入（sはstring型で宣言しておく必要がある。）<br>
# `cout <<  "Hello World" << endl`  // endl は改行<br>
#
# ### printf / scanf
# `scanf("%d%d%d", &a, &b, &c);` &nbsp;　//スペース、改行文字(\n),タブ(\t)で区切り、変数に同上
#   ただし文字列を入力する場合はscanfは不可。&nbsp;　cinを使う。<br>
# `ptintf( "hoge %d hoge\n",x);`&nbsp; // 変数x の値をフォーマット指定子で %に埋め込み表示。 \nは改行<br>
#   printfで文字列を出力する場合は以下のように書く<br>
# ```C++
# 　int main() {
#   　string s = "hello　world";
#   　// フォーマット指定子 %s を用い s.c_str() を渡す
#   　printf("%s\n", s.c_str());
# 　}
# ```
# ### scanf,printfで使うフォーマット指定子
#
# |型:フォーマット指定子|
# | ----  |
# |int : %d |
# | int64_t : %ld（%lld） |
# | double : %lf  |
# | char : %c |
#
#
# ## 論理演算子
# 演算子	         | 意味                           |	真になる時
#  ---- | ---- | ----
# !(条件式)          |	条件式の結果の反転              |	条件式が偽
# 条件式1 &&  条件式2 |	条件式1が真 かつ 条件式2が真      |	条件式1と条件式2のどちらも真
# 条件式1 || 条件式2	 | 条件式1が真 または 条件式2が真   | 条件式1と条件式2のどちらかが真
#
#
# ## 文字列、文字
# `string str = "Hello";`&nbsp;  // "	を使用<br>
# `str.size();`&nbsp;  //5
# `str.at(0);`&nbsp;   // H　char型
# `char c = 'a';`&nbsp;  // 'を使用
# `string  str  =  to_string(int);`&nbsp;  // 数(int)を文字列に変換
# `const char *c = str.c_str();`&nbsp;　　// 文字列(str)をの先頭のcharのポインタを取得   ->c[位置]で文字を取得
#
# ### 配列１(静的配列)
# `int data[要素数];`&nbsp;  //int型の配列変数dataを指定の要素数で宣言
# `int data[5] = {1,2,3,4,5};`&nbsp; // 配列の初期化
# `data[0] = x;`&nbsp;  //配列変数の0番目に値を代入
# `sort(data, data+N+1);`&nbsp; // 0番からN番をソート。"data"は配列の0番目を指示。 algorithmの標準ライブラリ。
#
# ### 配列２(動的配列)
# `vector<int> vec;`&nbsp;//int型のデータ列を扱う配列変数vecが宣言される。
# `vector<int> vec(要素数,初期値);`&nbsp;初期値を省略した場合int型なら0、char型なら""で初期化
# `vector<int> vec = {1,2,3,4,5};`&nbsp; // 値を指定して初期化
#     配列変数で入力を受け取るには、十分な大きさで配列を初期化した後、.at(i)を使って一つずつ受け取っていく必要がある。<br>
# `vec.push_back(5);`&nbsp;  //配列の**末尾に**要素5を追加
# `vec.pop_back();`&nbsp; // 末尾の要素を削除
# `vec.size()`&nbsp; //配列のサイズ(要素数）を取得
# `vec.insert(位置,要素）`&nbsp;　//
# `sort(vec.begin(),vec.end());`&nbsp;//小さい順に整列　(sort後にreverse(vec.begin(),vec.end())で大きい順になる
# `copy(vec.begin(), vec.end(), copy_vec.begin())` &nbsp; // 配列vecを配列copy_vecにコピー（copy_vecのサイズはあらかじめvecと同じにしておく必要がある）
#
# ::要素が昇順に整列している場合の、特定の値の位置を出力するコード::
# ```C++
# auto iter = lower_bound(vec.begin() , vec.end() , key);  // key 以上の要素の最初の位置(のイテレータ)を返す
# int idx = distance(vec.begin() , iter) // keyの位置をintで返す。
# cout << "vec[" << idx << "] = " <<*iter << "\n"; //vec[idx] = x と出力
# ```
# **二重配列**
# `vector<vector<型名>> vec_2nd (N , vector<型名>(M,初期値)); `&nbsp;//二重配列(N*M)の宣言。初期値は省略可。
#
# ### bit演算
# `bitset<ビット数> 変数名;`&nbsp;  // bit配列の宣言　すべてのビットが0の状態で初期化される
# `bitset<ビット数> 変数名("ビット列(長さはビット数に合わせる)");`&nbsp; // 指定したビット列で初期化。指定は十進数でも可。
# 演算子
#   ビット毎の  AND演算:& | OR演算:| | XOR演算:^ |NOT演算:~ | 論理左シフト演算:<< |
#
# `変数名.set(位置,値)`&nbsp; 　　// 特定の位置のbit値を変更する。値を省略すれば1になる。　　位置は右から0,1,2,3…
# `変数名.test(調べる位置)`&nbsp;　-> bool&nbsp;　// bit値が1(->true)か0(->false)かを判定
# `変数名.all`&nbsp; ->bool //すべてのbitが１のときtrue
# `変数名.any`&nbsp;//->bool&nbsp; 1のbitが存在するときtrue
# `変数名.count`&nbsp; //->int&nbsp; １のbit数を数える
# `変数名.to_ullong()`&nbsp; ->整数(10進数)&nbsp; ただし、bit数が64bit以内に限る
# ２進数リテラル表記も可　uint32_t 変数名 = 0b****;
#
# ::全検索のひな形::
# ```C++
# for (int tmp = 0; tmp < (1 << ビット数); tmp++) {
#     bitset<ビット数> s(tmp);
#     // (ビット列sに対する処理)
# }
# ```
#
# ### 範囲for 文
# ```C++
# int main() {
#   vector<int> a = {1, 3, 2, 5};
#   for (int x : a) {
#     cout << x << endl;
#   }
# }
# ```
#
# #### 三項演算子（条件演算子)
# `条件式 ? 真の時の式 : 偽の時の式` &nbsp;// 例　 a < b ? a : b  aとb の小さいほうを選ぶ
#
# #### ラムダ式
# `auto 関数名 = [](引数の型1 引数名1, 引数の型2, 引数名2, ...) { 関数の処理 };`
# 他の関数の内部で使う場合のコード。*末尾に `;`が必要*
# ```C++
# 　　   int main(){
#           auto my_min = [](int a ,int b){
#              if(a < b){return a;}
#                  else {return b;}
#           };
#              //他の処理
#                  }
#   ```
#
# **再帰関数として利用する場合**
# `function<返り値の型(引数の型1, 引数の型2, ...)> 関数名 = [&](引数の型1 引数名1, 引数の型2, 引数名2, ...) { 関数の処理 };`
#
# ## コンテナ
#
# #### 種類
# + 配列：vector, array, deque   //vector はあらかじめサイズを指定しなくても利用できる。動的配列。添え字でのアクセスや要素の追加ができる
# + リスト：list, forward_list　　　//listはイテレータを使うことで要素の挿入や削除ができる。添え字での要素へのアクセスは不可。
# + 二分木（赤黒木）：map, multimap, set, multiset
# + ハッシュテーブル：unordered_map, unordered_multimap, unordered_set, unordered_multiset
#
# #### 計算量
# 　　　-　|　　ランダム・アクセス|　挿入削除|　　検索
# ----| ---- | ----  | ----
# 配列　　　　  |　O(1)　　|　O(N)　  |　　　O(N) ただし、ソート済み配列の二分探索は O(log N)
# リスト　　　  |　O(N)　　|　O(1)　　|　　　O(N)
# 二分木　　　  |　O(N)　　|　O(log N)|　　  O(log N)
# ハッシュテーブル　|O(N)　|　O(1)　　|　　　 O(1)
#
#
# + vector
#   vector<型>　変数名(要素数 , 初期値);  //宣言
#   vector<型> 変数名　= {x , y, z}       //初期化
#   変数名.push_back(値)　  // 要素の追加
#   変数名.pop_back()     //末尾の要素の削除
#
#
# + map
# 　map<Keyの型, Valueの型> 変数名;　// 宣言
# 　変数名[key] = value;   // 要素の追加
# 　変数名.erase(key);	// 要素を削除
#   変数名.at(key);   -> value;      //要素へアクセス
# 　変数名.count(key);  -> bool  //key要素の有無の判定
# 　変数名.size();  ->int   //要素数を取得
#
# + queue
# 　queue<型>  変数名;  //宣言
# 　変数名.push(値);　//要素を追加
# 　変数名.front(); 　　//先頭の要素を取得
# 　変数名.pop(); 　　　//先頭の要素が削除
# 　変数名.size(); ->int
# 　変数名.empty(); ->bool
#
# + priority_queue
# 　priority_queue　<型, vector<型>, greater<型>> 変数;
# 　変数名.top(); 　　//先頭の要素を取得
# 　**他のメソッドはqueueと共通
# 　priority_queue<型, vector<型>, greater<型>> 変数;
# 　**小さい順に取り出される
#
# + set
#   set<値の型> 変数名;       //宣言
#      変数名.insert(値);    //
#      変数名.erase(値);     //
#
#
# ### 計算量と処理時間の目安
#
# |N		|O(1)	 | O(logN)	|O(N)		|O(NlogN)	 |O(N^2)		|O(2^N)|
# |---- | ---- | ---- |    ----  |  ----    | ---- | ---- |
# |1		|一瞬		|一瞬	 |	一瞬		|一瞬		|一瞬		|	一瞬 |
# |10		|一瞬		|一瞬	 |	一瞬		|一瞬		|一瞬		|	一瞬 |
# |1000	|	一瞬	|一瞬	 |	一瞬		|一瞬		|0.01秒くらい	|地球爆発|
# |10^6 |	一瞬	|一瞬	 |  0.01秒くらい |0.2秒くらい	|3時間くらい		|地球爆発|
# |10^8 |	一瞬	|一瞬	 | 1秒くらい	|30秒くらい	|3年くらい		|地球爆発|
# |10^16|	一瞬	|一瞬	 |3年くらい	|170年くらい	|地球爆発		|地球爆発|
#
# N=10 ^6 くらいまでの入力で1秒以内に計算を終えるプログラムを作成するのであれば、
# O(N^2 )のアルゴリズムでは間に合わないので、O(N)のアルゴリズムを用いて実装する必要があります。
# 1秒あたり 10^8(1億) 回くらいの計算ができることを覚えておきましょう
# sort -- O(NlogN)  reverse -- O(N)#
